# %%
import pandas as pd
ecom =  pd.read_csv("ecom - ecom.csv")
ecom
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
ecom.shape
# Out:
# (10999, 12)

# %%
ecom.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
ecom.tail()
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 10994                1                  252                5
# 10995                1                  232                5
# 10996                4                  242                5
# 10997                2                  223                6
# 10998                5                  155                5
#
#       Product_importance Gender  Discount_offered  Weight_in_gms  \
# 10994             medium      F                 1           1538
# ...

# %%
ecom.iloc[179]
# Out:
# ID                        180
# Warehouse_block             F
# Mode_of_Shipment         Ship
# Customer_care_calls         5
# Customer_rating             5
# Cost_of_the_Product       255
# Prior_purchases             4
# Product_importance     medium
# Gender                      M
# Discount_offered            3
# Weight_in_gms            3440
# Reached.on.Time_Y.N         1
# Name: 179, dtype: object

# %%
    import pandas as pd
    ecom =  pd.read_csv("ecom - ecom.csv")
    ecom.sort_values("Mode_of_Shipment", inplace = True)
    filter1 = ecom["Mode_of_Shipment"]=="Flight "
    filter2 = ecom["Weight_in_gms"]<700
    ecom.where(filter1 & filter2, inplace = True)
    ecom
# Out:
#        ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0     NaN             NaN              NaN                  NaN
# 9871  NaN             NaN              NaN                  NaN
# 9872  NaN             NaN              NaN                  NaN
# 9873  NaN             NaN              NaN                  NaN
# 9874  NaN             NaN              NaN                  NaN
# ...    ..             ...              ...                  ...
# 4352  NaN             NaN              NaN                  NaN
# 4353  NaN             NaN              NaN                  NaN
# 4354  NaN             NaN              NaN                  NaN
# 4348  NaN             NaN              NaN                  NaN
# 10998 NaN             NaN              NaN                  NaN
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                  NaN                  NaN              NaN
# 9871               NaN                  NaN              NaN
# ...

# %%
import dask.dataframe as dd

ecom = dd.read_csv("ecom - ecom.csv")

ecome = ecom[(ecom['Mode_of_Shipment'] =="Flight") & (ecom['Weight_in_gms'] > 700)]

ecome = ecom.compute()
ecome
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
 ecom.mean(Customer_rating)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14000/2906625910.py in <module>
# ----> 1 ecom.mean(Customer_rating)
#
# NameError: name 'Customer_rating' is not defined
